# %% [markdown]
# # Capstone Project 1 - Finance

# %% [markdown]
# In this project, mainly learning the concepts of Pandas and Data visualization. I will be
# doing EDA for the finance data and mainly focusing on bank stocks and how they progressed
# throughout the financial crisis all the way to early 2016

# %%
import pandas as pd
import numpy as np
import pandas_datareader as dr
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline              

#importing all the necessory liabraries

# %% [markdown]
# ### Getting Data of each bank:
#
#     - Goldman Sachs
#
#     - Morgan Stanley
#
#     - Bank of America
#
#     - CitiGroup
#
#     - JPMorgan Chase
#
#     - Wells Fargo

# %%
GS = dr.data.get_data_yahoo('GS',start='2006-01-01',end='2016-01-01')
GS.head()    #Goldman Sachs
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2006-01-03  129.440002  124.230003  126.699997  128.869995  6188700.0
# 2006-01-04  128.910004  126.379997  127.349998  127.089996  4861600.0
# 2006-01-05  127.320000  125.610001  126.000000  127.040001  3717400.0
# 2006-01-06  129.250000  127.290001  127.290001  128.839996  4319600.0
# 2006-01-09  130.619995  128.000000  128.500000  130.389999  4723500.0
#
#              Adj Close
# Date
# 2006-01-03  105.687309
# 2006-01-04  104.227493
# 2006-01-05  104.186478
# 2006-01-06  105.662666
# 2006-01-09  106.933891

# %%
MS = dr.data.get_data_yahoo('BAC',start='2006-01-01',end='2016-01-01')
MS.head()  #Morgan Stanley
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  34.596096
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  34.228691
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  34.272778
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  34.221321
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  34.243366

# %%
BAC = dr.data.get_data_yahoo('BAC',start='2006-01-01',end='2016-01-01')
BAC.head()  #Bank of america
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  34.596096
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  34.228691
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  34.272778
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  34.221321
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  34.243366

# %%
C = dr.data.get_data_yahoo('C',start='2006-01-01',end='2016-01-01')
C.head()  #citigroup
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2006-01-03  493.799988  481.100006  490.000000  492.899994  1537600.0
# 2006-01-04  491.000000  483.500000  488.600006  483.799988  1870960.0
# 2006-01-05  487.799988  484.000000  484.399994  486.200012  1143160.0
# 2006-01-06  489.000000  482.000000  488.799988  486.200012  1370210.0
# 2006-01-09  487.399994  483.000000  486.000000  483.899994  1680740.0
#
#              Adj Close
# Date
# 2006-01-03  379.511047
# 2006-01-04  372.504486
# 2006-01-05  374.352448
# 2006-01-06  374.352448
# 2006-01-09  372.581421

# %%
JPM = dr.data.get_data_yahoo('BAC',start='2006-01-01',end='2016-01-01')
JPM.head()    #JPMorgan Chase
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  34.596096
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  34.228691
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  34.272778
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  34.221321
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  34.243366

# %%
WFC = dr.data.get_data_yahoo('BAC',start='2006-01-01',end='2016-01-01')
WFC.head()  #Wells Fargo
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  34.596096
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  34.228691
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  34.272778
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  34.221321
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  34.243366

# %% [markdown]
# #### 1. Create a list of the ticker symbols (as strings) in alphabetical order. Call this list: tickers

# %%
tickers = ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']

# %%
df = dr.data.get_data_yahoo(tickers,start='2006-01-01',end='2016-01-01')
df.head()
# Out:
# Attributes  Adj Close                                                \
# Symbols           BAC           C          GS        JPM         MS
# Date
# 2006-01-03  34.596096  379.511047  105.687309  26.974699  36.975834
# 2006-01-04  34.228691  372.504486  104.227493  26.818987  37.001183
# 2006-01-05  34.272778  374.352448  104.186478  26.900234  37.102646
# 2006-01-06  34.221321  374.352448  105.662666  27.089762  37.140705
# 2006-01-09  34.243366  372.581421  106.933891  27.529747  37.533863
#
# Attributes                 Close                                     ...  \
# Symbols           WFC        BAC           C          GS        JPM  ...
# Date                                                                 ...
# 2006-01-03  20.723480  47.080002  492.899994  128.869995  40.189999  ...
# 2006-01-04  20.483118  46.580002  483.799988  127.089996  39.619999  ...
# 2006-01-05  20.460379  46.639999  486.200012  127.040001  39.740002  ...
# ...

# %%
df.shape
# Out:
# (2517, 36)

# %% [markdown]
# ####  2. Use pd.concat to concatenate the bank dataframes together to a single data frame called bank_stocks. Set the keys argument equal to the tickers list. Also pay attention to what axis you concatenate on

# %%
bank_stocks = pd.concat([BAC, C, GS, JPM, MS, WFC],axis=1,keys=tickers)
bank_stocks.head()
# Out:
#                   BAC                                                          \
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  34.596096
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  34.228691
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  34.272778
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  34.221321
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  34.243366
#
#                      C                                      ...         MS  \
#                   High         Low        Open       Close  ...       Open
# Date                                                        ...
# 2006-01-03  493.799988  481.100006  490.000000  492.899994  ...  46.919998
# 2006-01-04  491.000000  483.500000  488.600006  483.799988  ...  47.000000
# ...

# %% [markdown]
# ### 3.. Set the column name levels

# %%
bank_stocks.columns.names = ['Bank Ticker','Stock Info']

# %%
bank_stocks.head()
# Out:
# Bank Ticker        BAC                                               \
# Stock Info        High        Low       Open      Close      Volume
# Date
# 2006-01-03   47.180000  46.150002  46.919998  47.080002  16296700.0
# 2006-01-04   47.240002  46.450001  47.000000  46.580002  17757900.0
# 2006-01-05   46.830002  46.320000  46.580002  46.639999  14970700.0
# 2006-01-06   46.910000  46.349998  46.799999  46.570000  12599800.0
# 2006-01-09   46.970001  46.360001  46.720001  46.599998  15619400.0
#
# Bank Ticker                      C                                      ...  \
# Stock Info   Adj Close        High         Low        Open       Close  ...
# Date                                                                    ...
# 2006-01-03   34.596096  493.799988  481.100006  490.000000  492.899994  ...
# 2006-01-04   34.228691  491.000000  483.500000  488.600006  483.799988  ...
# 2006-01-05   34.272778  487.799988  484.000000  484.399994  486.200012  ...
# ...

# %%
bank_stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2517 entries, 2006-01-03 to 2015-12-31
# Data columns (total 36 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   (BAC, High)       2517 non-null   float64
#  1   (BAC, Low)        2517 non-null   float64
#  2   (BAC, Open)       2517 non-null   float64
#  3   (BAC, Close)      2517 non-null   float64
#  4   (BAC, Volume)     2517 non-null   float64
#  5   (BAC, Adj Close)  2517 non-null   float64
#  6   (C, High)         2517 non-null   float64
#  7   (C, Low)          2517 non-null   float64
#  8   (C, Open)         2517 non-null   float64
#  9   (C, Close)        2517 non-null   float64
#  10  (C, Volume)       2517 non-null   float64
#  11  (C, Adj Close)    2517 non-null   float64
#  12  (GS, High)        2517 non-null   float64
#  13  (GS, Low)         2517 non-null   float64
#  14  (GS, Open)        2517 non-null   float64
# ...

# %%
bank_stocks.isnull().sum()     #checking null values
# Out:
# Bank Ticker  Stock Info
# BAC          High          0
#              Low           0
#              Open          0
#              Close         0
#              Volume        0
#              Adj Close     0
# C            High          0
#              Low           0
#              Open          0
#              Close         0
#              Volume        0
#              Adj Close     0
# GS           High          0
#              Low           0
#              Open          0
#              Close         0
#              Volume        0
#              Adj Close     0
# JPM          High          0
#              Low           0
#              Open          0
#              Close         0
#              Volume        0
#              Adj Close     0
# MS           High          0
#              Low           0
#              Open          0
#              Close         0
#              Volume        0
#              Adj Close     0
# WFC          High          0
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# ### a. What is the max Close price for each bank's stock throughout the time period?

# %%
bank_stocks.xs('Close', level='Stock Info', axis = 1).max()
# Out:
# Bank Ticker
# BAC     54.900002
# C      564.099976
# GS     247.919998
# JPM     54.900002
# MS      54.900002
# WFC     54.900002
# dtype: float64

# %% [markdown]
# ### b. Create a new empty DataFrame called returns. This dataframe will contain the returns for each bank's stock. returns are typically defined by:

# %%
returns = pd.DataFrame()

# %% [markdown]
# ### c. Use pandas pct_change() method on the Close column to create a column representing this return value.
# ### Create a for loop that goes and for each Bank Stock Ticker creates this returns column and set's it as a column in the returns DataFrame.

# %%
for t in tickers:
    returns[t+' Return'] = bank_stocks[t]['Close'].pct_change()
returns.head()

#Our first value has NaN because you can not get a percent return on the very first day 
#because there is nothing in the past to compare it to
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.010620  -0.010620   -0.010620
# 2006-01-05    0.001288  0.004961  -0.000393    0.001288   0.001288    0.001288
# 2006-01-06   -0.001501  0.000000   0.014169   -0.001501  -0.001501   -0.001501
# 2006-01-09    0.000644 -0.004731   0.012030    0.000644   0.000644    0.000644

# %% [markdown]
# ### d. Create a pairplot using seaborn of the returns dataframe. What stock stands out to you? Can you figure out why?

# %%
sns.pairplot(returns[1:])

# %% [markdown]
# ### e. Checkout more about the behaviour of Citigroup

# %%
for t in tickers:
    bank_stocks[t]['Close'].plot(figsize=(12,4),label=t)
plt.legend()

# %%
bank_stocks.xs('Close', axis=1, level='Stock Info').max()

#The bank with the highest stock price is Citigroup
# Out:
# Bank Ticker
# BAC     54.900002
# C      564.099976
# GS     247.919998
# JPM     54.900002
# MS      54.900002
# WFC     54.900002
# dtype: float64

# %%
C['Close'].idxmax()

#On the below date did Citigroup stock reach its highest price
# Out:
# Timestamp('2006-12-27 00:00:00')

# %% [markdown]
# Citi Group line and time when it has gone down

# %%
plt.figure(figsize=(12,6))
C['Close'].loc['2008-01-01':'2009-01-01'].rolling(window=30).mean().plot(label='30 Day Avg')
C['Close'].loc['2008-01-01':'2009-01-01'].plot(label='C - CLOSE PRICE')
plt.legend()    #30 Day avg of stock price

# %%
for tick in tickers:
    bank_stocks[tick]['Close'].plot(label=tick, figsize=(12,6))
plt.legend()

# Now we can clearly see the crash of Citigroup in 2008-09

# %%
#displot of the 2008 returs for Citigroup 

plt.figure(figsize=(10,8))
ax = sns.distplot(returns.loc['2008-01-01':'2008-12-31']['C Return'], color='red', bins=50)
ax.set_title('2008 CitiGroup Returns')
ax.set_xlabel('Returns')
ax.set_ylabel('Numbers of Returns')
# Out:
# Text(0, 0.5, 'Numbers of Returns')

# %% [markdown]
# * Notice that the standard deviation is actually more stretched out.

# %% [markdown]
# ### f. Using this returns DataFrame, figure out on what dates each bank stock had the best and worst single day returns. You should notice that 4 of the banks share the same day for the worst drop, did anything significant happen that day?

# %%
returns.idxmax()   # Biggest single day best returns or gain
# Out:
# BAC Return   2009-04-09
# C Return     2008-11-24
# GS Return    2008-11-24
# JPM Return   2009-04-09
# MS Return    2009-04-09
# WFC Return   2009-04-09
# dtype: datetime64[ns]

# %%
returns.idxmin()  # Biggest single day losses
# Out:
# BAC Return   2009-01-20
# C Return     2009-02-27
# GS Return    2009-01-20
# JPM Return   2009-01-20
# MS Return    2009-01-20
# WFC Return   2009-01-20
# dtype: datetime64[ns]

# %% [markdown]
# ### g. You should have noticed that Citigroup's largest drop and biggest gain were very close to one another, did anything significant happen in that time frame?

# %% [markdown]
# - Best Single Day Gain
# - It can be seen that of the 6 banks, 5 had their worst performance on the same day.

# %% [markdown]
# ### h. Take a look at the standard deviation of the returns, which stock would you classify as the riskiest over the entire time period? Which would you classify as the riskiest for the year 2015?

# %%
returns.std()
# Out:
# BAC Return    0.036647
# C Return      0.038672
# GS Return     0.025390
# JPM Return    0.036647
# MS Return     0.036647
# WFC Return    0.036647
# dtype: float64

# %%
returns.std().plot(kind='bar', color='Green')
plt.ylabel('Standard Deviation')
plt.title('Banks Standard Deviation', fontsize=15)
sns.despine()

# %% [markdown]
# Riskiest stocks is Citigroup

# %% [markdown]
# ### i. Create a distplot using seaborn of the 2015 returns for Morgan Stanley

# %%
plt.figure(figsize=(10,8))
ax = sns.distplot(returns.loc['2015-01-01':'2015-12-31']['MS Return'], color='black', bins=50)
ax.set_title('2015 Morgan Stanley Returns')
ax.set_xlabel('Returns')
ax.set_ylabel('Numbers of Returns')
# Out:
# Text(0, 0.5, 'Numbers of Returns')

# %% [markdown]
# We can see that the distribution is pretty stable.

# %% [markdown]
# ### j. Create a distplot using seaborn of the 2008 returns for CitiGroup

# %%
sns.distplot(returns.loc['2008-01-01':'2008-12-31']['C Return'],color='black',bins=100)

# %% [markdown]
# ## Visualization in depth

# %% [markdown]
# ### a. Create a line plot showing Close price for each bank for the entire index of time. (Hint: Try using a for loop, or use .xs to get a cross section of the data.)

# %%
bank_stocks.xs('Close', level='Stock Info', axis = 1).plot(figsize=(12,4),label=t)

# %% [markdown]
# ### b. Plot the rolling 30 day average against the Close Price for Bank Of America's stock for the year 2008

# %%
plt.figure(figsize=(12,6))
BAC['Close'].loc['2008-01-01':'2009-01-01'].rolling(window=30).mean().plot(label='30 Day Avg')
BAC['Close'].loc['2008-01-01':'2009-01-01'].plot(label='BAC - CLOSE PRICE')
plt.legend()

# %% [markdown]
# ### c. Create a heatmap of the correlation between the stocks Close Price.

# %%
sns.heatmap(bank_stocks.xs(key='Close',axis=1,level='Stock Info').corr(),annot=True)

# %% [markdown]
# ### d. Use seaborn's clustermap to cluster the correlations together

# %%
sns.clustermap(bank_stocks.xs(key='Close',axis=1,level='Stock Info').corr(),annot=True)
